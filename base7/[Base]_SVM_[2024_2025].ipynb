# %% [markdown]
# # <img src="data:image/jpeg;base64,..." width="50"/>
#
# # Машинное обучение. ВМК МГУ

# %% [markdown]
# # Практическое задание 7: SVM
# ## Уровень: <font color='SkyBlue'>**Базовый (Base)**</font>

# %% [markdown]
# # О формате сдачи
#
# 🔷 **<font color='plum'>При решении ноутбука используйте данный шаблон</font>**
#
#     ✅ Можно добавлять новые ячейки любых типов
#     ❌ Не нужно удалять текстовые ячейки c разметкой частей ноутбука и формулировками заданий
#
#
# 🔷 **<font color='plum'>При оценивании задач учитывается код</font>**
#
#     ✅ Задания, в которых необходим код, обычно помечаются фразами "Your code here"/"Ваш код" и аналогичными
#     ❌ Ответы на вопросы без сопутствующего кода оцениваются в 0 баллов
#     ❌ Наличе работоспособного кода в ноутбуке, если на сказано иного, обязательно
#
# 🔷 **<font color='plum'>При оценивании задач учитываются выводы</font>**
#
#     ✅ Задания, в которых необходимы выводы, обычно помечаются фразами Вывод"/"Ответ на вопрос"/"Ваш текст" и аналогичными
#     ✅ Обычно выводы подразумевают под собой текстовый ответ (можно писать markdown, latex).
#     ✅ Сопутствующие изображения, графики, таблички - приветствуются!
#     ❌ При отсутствии выводов задание не засчитается на полный балл

# %% [markdown]
# Цель данного задания:
#
# * Изучите работу модели SVM
# * Поймете, как с её помощью можно строить нелинейные разделяющие поверхности
# * Потренируетесь в подборе оптимальных параметров на обучающей выборке для достижения наилучшего качества на закрытой выборке (ML-решение)
#
# -------
# <font color="white" style="opacity:0.2024"></font>
# <font color=DarkOrange>**Примерное время выполнения (execution time/время выполнения, если нажать run all) всех ячеек ноутбука при правильной реализации: до 10 минут </font>**

# %% [markdown]
# # Подготовка рабочей среды
#
# Сначала установим нужные нам версии библиотек. Мы гарантируем, что в данных версиях задание будет корректно отрабатывать.
#
# После установки нужных версий, **возможно,** нужно перезагрузить среду (runtime), но скорее всего вам это не понадобится
#
#
# На скачивание файла и установку понадобится не более 5 минут.
#
# <font color='OrangeRed'>**Важно!**</font>
#
# Устанавливать нужные версии нужно каждый раз, когда создается новый рантайм. Например, если вы 2 часа подряд делаете это задание, то подготовить библиотеки достаточно 1 раз. Но если вы, например, начали в понедельник, затем закрыли/выключили ноутбук, то при продолжении в среду, вам нужно будет запустить рантайм заново и следовательно заново установить библиотеки.
#
# <font color='OrangeRed'>**Важно!**</font>
# Если вы предпочитаете делать практические задания на своем личном ноутбуке, то проверьте, что вы установили рабочее окружение в [соответствии с гайдом](https://github.com/MSU-ML-COURSE/ML-COURSE-24-25/blob/main/tutorials/%D0%A2%D1%83%D1%82%D0%BE%D1%80%D0%B8%D0%B0%D0%BB%20%D0%BF%D0%BE%20%D1%83%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BA%D0%B5%20%D1%80%D0%B0%D0%B1%D0%BE%D1%87%D0%B5%D0%B3%D0%BE%20%D0%BE%D0%BA%D1%80%D1%83%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B2%20Python%20%D0%B4%D0%BB%D1%8F%20%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%20(2).pdf)

# %%
# # !!! Данный блок будет работать только в Google-Colab !!!
# ! gdown 10k8Hwn9kpK9SpK4IEj4-EaWQZqgYT5-Q
# ! pip install -r /content/requirements_2024_25_for_colab_small.txt

# %% [markdown]
# Проверим версию библиотеки:

# %%
import catboost
assert(catboost.__version__ == '1.2.7')

# %% [markdown]
# Теперь можно приступать к выполнению задания! :)

# %% [markdown]
# -----------
# <font color="white" style="opacity:0.2023"></font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from copy import copy

# %% [markdown]
# Если Вы дальтоник, то можете воспользоваться готовой colormap из matplotlib (или найти свою):
# ```
# plt.style.use('tableau-colorblind10')
# ```

# %% [markdown]
# Приведем вспомогательный код

# %%
from matplotlib.colors import ListedColormap

from sklearn.svm import LinearSVC, SVC
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate, train_test_split
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
from sklearn.datasets import make_blobs, make_circles, make_moons

# %%
def make_moons_cls(size=1000, d=2):
    X, y = make_moons(n_samples=size, noise=0.15)
    if d > 2:
        X = np.concatenate((X, np.random.normal(size=(size, d-2))), axis=1)
    return X, y

def make_circles_cls():
    X, y = make_circles()

def generate_data_with_imb_classes(size1=100, size2=10):
    X = np.r_[(
        np.random.normal(loc=1.0, size=(size1, 2)),
        np.random.normal(loc=0.5, size=(size2, 2))
    )]

    y = np.ones(len(X))
    y[-size2:] = 0
    return X, y

# %%
def plot_separating_surface(X, y, cls, view_support=False, title=''):
    x_min = min(X[:, 0]) - 0.1
    x_max = max(X[:, 0]) + 0.1
    y_min = min(X[:, 1]) - 0.1
    y_max = max(X[:, 1]) + 0.1
    h = 0.005
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                             np.arange(y_min, y_max, h))
    Z = cls.predict(np.c_[xx.ravel(), yy.ravel()])

    plt.figure(figsize=(10, 10))
    if title:
        plt.title(title)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', s=40, cmap=cm_bright)
    if view_support:
        plt.scatter(X[cls.support_, 0], X[cls.support_, 1],
                    c=y[cls.support_], edgecolors='k', s=150, cmap=cm_bright)
    Z = Z.reshape(xx.shape)
    plt.xticks(())
    plt.yticks(())
    plt.contourf(xx, yy, Z, cmap=cm, alpha=.3)
    plt.show()

# %% [markdown]
# # Загрузка данных

# %%
import gdown
gdown.download_folder('https://drive.google.com/drive/folders/1bp39_Jj0edo1lzxZ3DIoChsOVy5DVi1R?usp=sharing')
# Out:
# Retrieving folder contents
# Retrieving folder 1tv605hGxdQtd4zC787DbcRF0312gDeK_ imbalanced
# Processing file 14zd2xHDChSHtMWQ_TUzM8td7s8gzCO2u X_imb_test.npz.npy
# Processing file 1Qed066d3gUsUOZiUZu6aCrIH9f0yWKSc X_imb.npz.npy
# Processing file 1uD87Xbh4MMBBn5fsScrknI54SINIqory y_imb_test.npz.npy
# Processing file 1RR2VU_6WJMLo88k8C1VzBwb2Ibnz1yJf y_imb.npz.npy
# Retrieving folder 1uoI6vZWwIII1jd2k5TtsZTJ3JOkK0G6O public
# Processing file 1Win7ZtHLHEbDtX6x6O7vBJHwJviQxbp5 cX_test.npy
# Processing file 1MowPnLFAMEjjcAjDA4skE4OUFdmaiSY6 cX_train.npy
# Processing file 1VYA4N5wCQhwteQSZkDogFTha2xRv0FgW cy_train.npy
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=14zd2xHDChSHtMWQ_TUzM8td7s8gzCO2u
# To: /home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/X_imb_test.npz.npy
# 100%|██████████| 2.05k/2.05k [00:00<00:00, 5.10MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Qed066d3gUsUOZiUZu6aCrIH9f0yWKSc
# To: /home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/X_imb.npz.npy
# 100%|██████████| 2.05k/2.05k [00:00<00:00, 501kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1uD87Xbh4MMBBn5fsScrknI54SINIqory
# To: /home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/y_imb_test.npz.npy
# 100%|██████████| 1.09k/1.09k [00:00<00:00, 3.53MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1RR2VU_6WJMLo88k8C1VzBwb2Ibnz1yJf
# To: /home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/y_imb.npz.npy
# 100%|██████████| 1.09k/1.09k [00:00<00:00, 2.50MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Win7ZtHLHEbDtX6x6O7vBJHwJviQxbp5
# To: /home/andrey/Desktop/mmo/base7/05-SVM/public/cX_test.npy
# 100%|██████████| 8.13k/8.13k [00:00<00:00, 20.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MowPnLFAMEjjcAjDA4skE4OUFdmaiSY6
# To: /home/andrey/Desktop/mmo/base7/05-SVM/public/cX_train.npy
# 100%|██████████| 32.1k/32.1k [00:00<00:00, 354kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VYA4N5wCQhwteQSZkDogFTha2xRv0FgW
# To: /home/andrey/Desktop/mmo/base7/05-SVM/public/cy_train.npy
# 100%|██████████| 6.53k/6.53k [00:00<00:00, 10.6MB/s]
# Download completed
# ['/home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/X_imb_test.npz.npy',
#  '/home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/X_imb.npz.npy',
#  '/home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/y_imb_test.npz.npy',
#  '/home/andrey/Desktop/mmo/base7/05-SVM/imbalanced/y_imb.npz.npy',
#  '/home/andrey/Desktop/mmo/base7/05-SVM/public/cX_test.npy',
#  '/home/andrey/Desktop/mmo/base7/05-SVM/public/cX_train.npy',
#  '/home/andrey/Desktop/mmo/base7/05-SVM/public/cy_train.npy']

# %% [markdown]
# # SVM и разделяющая поверхность

# %% [markdown]
# На лекции вы изучили, что линейная, с виду, модель SVM, при помощи некоторых "фокусов", называемых ядрами, умеет строить нелинейные поверхности. В данном ноутбуке посмотрим, как это все работает на практике, и какие гиперпараметры настройки у этого метода есть.
#
# <font color='MediumTurquoise'>**Историческая справка:**</font> Метод опорных векторов (SVM) стал популярным в 90-х годах, особенно с 1995 года, благодаря своей эффективности в задачах классификации и способности обрабатывать высокоразмерные данные. Он также привлек внимание благодаря использованию ядровых функций, что позволяло решать нелинейные задачи. Однако с появлением более сложных методов, таких как глубокое обучение, и увеличением объема данных, SVM стал менее популярным, поскольку более современные алгоритмы демонстрировали лучшие результаты на больших наборах данных и обеспечивали более простую настройку.

# %% [markdown]
# ## <font color='DarkOrange'>**Задание 1 [1 балл]**</font>

# %% [markdown]
# В ячейке ниже генерируется выборка, состоящая из объектов двух классов. Каждый объект представлен двумя координатами, так что объекты этой выборки можно отобразить на плоскости, используя функцию scatter из библиотеки matplotlib.
#
#
#
# В этом задании вам надо будет обучить линейную разделяющую поверхность с помощью $\mbox{sklearn.svm.SVC(kernel='linear')}$, а также нелинейную c rbf-ядром с помощью $\mbox{sklearn.svm.SVC(kernel='rbf')}$. Остальные параметры методов можете оставить дефолтными. Делить выборку на обучение и валидацию сейчас не требуется, так как нас будет пока интересовать только форма разделяющей кривой.

# %%
X, y = make_moons_cls()
linear_svc = SVC(kernel='linear')
nonlinear_svc = SVC(kernel='rbf')

# %% [markdown]
# Визуализируем выборку

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X[y == 0, 0], X[y == 0, 1], label='y=0')
plt.scatter(X[y == 1, 0], X[y == 1, 1], label='y=1')
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.legend()
plt.grid()

# %% [markdown]
# Обучите модели и визуализируйте разделяющую поверхность для обеих моделей с помощью функции plot_separating_surface(). Посчитайте точность (accuracy) на обучающей выборке для каждой из моделей.

# %%
linear_svc.fit(X, y)
plot_separating_surface(X, y, linear_svc)
print(f'Train Accuracy (linear): {accuracy_score(y, linear_svc.predict(X)):.3f}')
# Out:
# Train Accuracy (linear): 0.867

# %%
nonlinear_svc.fit(X, y)
plot_separating_surface(X, y, nonlinear_svc)
print(f'Train Accuracy (non linear): {accuracy_score(y, nonlinear_svc.predict(X)):.3f}')
# Out:
# Train Accuracy (non linear): 0.987

# %% [markdown]
# **Сделайте вывод**
# о получившихся результатах. Какая из моделей лучше подходит для данной выборки и почему?

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# По визуализированной разделяющей поверхности видно, что для данной задачи лучше пожходит нелинейная классификация с rbf ядром.

# %% [markdown]
# ## 2. Опорные объекты

# %% [markdown]
# Продолжаем работать с выборкой и моделями из первой части. Для линейной и rbf-моделей рассмотрим
#     опорные объекты, полученные после обучения. Визуализировать их можно, используя функуцию plot_separating_surface с параметром vis_support=True. Достанем опорные объекты из обученной модели с помощью поля model.support_.

# %%
plot_separating_surface(X, y, nonlinear_svc, view_support=True)

# %% [markdown]
# Обучим новые две модели $\mbox{SVC(kernel='rbf')}$, используя только опорные объекты построенные с помощью соответственно линейной (linear_svc) и нелинейной (nonlinear_svc) моделей из первой части.

# %%
# Учим модели только на опорных объектах
svc_on_linear_support = SVC(kernel='rbf').fit(X[linear_svc.support_, :], y[linear_svc.support_])
svc_on_rbf_support = SVC(kernel='rbf').fit(X[nonlinear_svc.support_, :], y[nonlinear_svc.support_])

# %%
plot_separating_surface(X, y, svc_on_linear_support)

# %%
plot_separating_surface(X, y, svc_on_rbf_support)

# %% [markdown]
# ### <font color='DarkOrange'>**Задание 2 [1 балл]**</font>
#
# Сравните полученные разделяющие поверхности с нелинейной моделью (nonlinear_svc) из задания 1. Какая из поверхностей больше похожа на нелинейнную модель из первой части и почему, опишите в выводе.

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# На нелинейную модель больше похожа модель обученная на опорных объектах нелинейной модели, потому что они лучше описывают границу разделения.

# %% [markdown]
# ---

# %% [markdown]
# Теперь обучим модель $\mbox{SVC(kernel='rbf')}$, используя все объекты кроме тех, что являлись опорными для нелинейной модели из первой части (nonlinear_svc) и сравним эту модель вместе с svc_on_rbf_support с нелинейной моделью из задания 1(nonlinear_svc). Визуализируйте разделяющие поверхности обеих моделей.

# %%
non_support_vectors = [i for i in range(len(X)) if i not in nonlinear_svc.support_]
svc_all_without_rbf_support = SVC(kernel='rbf').fit(X[non_support_vectors, :], y[non_support_vectors])

# %%
plot_separating_surface(X, y, svc_all_without_rbf_support)

# %%
plot_separating_surface(X, y, nonlinear_svc)

# %%
plot_separating_surface(X, y, svc_on_rbf_support)

# %% [markdown]
# ### <font color='DarkOrange'>**Задание 3 [1.5 баллa]**</font>

# %% [markdown]
# **Сделайте вывод:** Сильно ли полученные поверхности отличаются от той, что была получена в первом задании? Что произошло с пограничными объектами? Объясните полученные результаты.

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# Все границы имеют одинаковую форму, но захватывают разное количество объектов.
# Модель обученная на неопорных объектах модели из первого задания показала результат немного хуже начальной модели.
# Модель обученная на опорных объектах модели из первого задания показала результат немного лучше, чем результат нначальной модели.
# Это можно объяснить тем, что модели обучаются на разных данных. В первом случае обучающих хданных меньше и их границы расположены "глубже" чем в начальных данных. Во втором случае в целом обучающих данных меньше и они менее зашумлены.

# %% [markdown]
# # 4. Обучите лучшую SVM модель (ML-решение)

# %% [markdown]
# Возможность строить нелинейные поверхности может сильно улучшить качество, но и несет риск переобучения.
#     В этом задании предстоит обучить лучшую svm модель и получить хорошее качество на тесте в системе тестирования. Для контроля переобучения рекомендуется пользоваться кросс-валидацией. Для улучшения качества рекомендуется подбирать
#
# 1. параметр регуляризации C;
# 2. тип разделяющей кривой linear/rbf/poly;
# 3. степень в случае разделяющей кривой poly.
#
# Также не забывайте, что при решении задач машинного обучения полезно смотреть в данные :)

# %% [markdown]
# Все csv-таблицы с данными вы можете взять из публичного теста, который также есть в проверяющей системе. Для этого распакуйте архив с публичными тестами и положите файлы в рабочей директории (рядом с ноутбуком)

# %%
X_train = np.load('05-SVM/public/cX_train.npy')
y_train = np.load('05-SVM/public/cy_train.npy')
X_test = np.load('05-SVM/public/cX_test.npy')

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((800, 5), (800,), (200, 5))

# %%
X = X_train
y = y_train.ravel()

# %%
plt.scatter(X[y == 0, 4], X[y == 0, 3], label='y=0')
plt.scatter(X[y == 1, 4], X[y == 1, 3], label='y=1')
plt.legend()

# %% [markdown]
# **Отправьте код обучения модели с оптимальными параметрами в проверяющую систему, воспользовавшись приложенным шаблоном svm_solution.py. Кросс-валидацию параметров в посылаемом решении делать <font color='red'>не нужно</font> -- достаточно подобрать, например, их тут, а в решении уже обучать модель с оптимальными параметрами.**

# %% [markdown]
# # Сравнение с логистической регрессией

# %% [markdown]
# #### <font color='DarkOrange'>**Задание 4 [1.5 баллa]**</font>

# %% [markdown]
# В предыдущей части Вы обучили хорошую SVM модель, подбирая гиперпараметры модели. Давайте теперь попробуем обучить логистическую регрессию на этой же выборке, и по кросс-валидации оценить влияние гиперпараметров на линейную модель.

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


pipeline = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('classification', LogisticRegression(penalty='l2', max_iter=200, random_state=2024))
])

params = {
    'classification__solver': ['lbfgs', 'saga'],
    'classification__C': [0.01, 0.1, 1, 10, 100],
    'classification__penalty': ['l2', None],
    'classification__max_iter': [100, 200, 500]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=2024)

grid_search = GridSearchCV(estimator=pipeline, cv=cv, param_grid=params, scoring='accuracy', n_jobs=-1, verbose=3)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV 2/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.725 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s[CV 1/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.738 total time=   0.0s
#
# [CV 2/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.669 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.725 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.738 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.706 total time=   0.1s
# [CV 3/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.725 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.669 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.706 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.1s
# [CV 3/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.706 total time=   0.0s
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 5/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.669 total time=   0.0s[CV 3/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.725 total time=   0.0s
#
# [CV 5/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.1s
# [CV 2/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.669 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.738 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.725 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.706 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.738 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.738 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.669 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.738 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.725 total time=   0.1s
# [CV 4/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.706 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 5/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.669 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.1s
# [CV 5/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 3/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s[CV 1/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
#
# [CV 4/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 5/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.725 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s[CV 3/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
#
# [CV 2/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.794 total time=   0.0s
# [CV 4/5] END classification__C=0.01, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.1s
# [CV 1/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.794 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.725 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.794 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.725 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.794 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.725 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.725 total time=   0.0s[CV 3/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
#
# [CV 2/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.794 total time=   0.0s
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 4/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.794 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s[CV 4/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
#
# [CV 2/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.725 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.775 total time=   0.0s
# [CV 5/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 3/5] END classification__C=0.1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 1/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.738 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s[CV 4/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
#
# [CV 3/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.775 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.775 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.775 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.775 total time=   0.0s
# [CV 2/5] END classification__C=0.01, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.1s
# [CV 3/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.775 total time=   0.1s
# [CV 5/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 3/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 5/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 3/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 2/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s[CV 4/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
#
# [CV 1/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 2/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 2/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s[CV 4/5] END classification__C=10, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
#
# [CV 5/5] END classification__C=1, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 3/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 3/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 3/5] END classification__C=10, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 4/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 4/5] END classification__C=1, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.1s
# [CV 5/5] END classification__C=10, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 5/5] END classification__C=10, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=10, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.1s
# [CV 4/5] END classification__C=10, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=10, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# ...
# [CV 2/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s[CV 1/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
#
# [CV 4/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=200, classification__penalty=l2, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=100, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=100, classification__penalty=l2, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=500, classification__penalty=l2, classification__solver=saga;, score=0.719 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.781 total time=   0.0s
# [CV 2/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.806 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=200, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.800 total time=   0.0s
# [CV 1/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.781 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.769 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=lbfgs;, score=0.719 total time=   0.0s
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/andrey/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.806 total time=   0.0s
# [CV 3/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.769 total time=   0.0s
# [CV 4/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.800 total time=   0.0s
# [CV 5/5] END classification__C=100, classification__max_iter=500, classification__penalty=None, classification__solver=saga;, score=0.719 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2024, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('classification',
#                                         LogisticRegression(max_iter=200,
#                                                            random_state=2024))]),
#              n_jobs=-1,
#              param_grid={'classification__C': [0.01, 0.1, 1, 10, 100],
#                          'classification__max_iter': [100, 200, 500],
#                          'classification__penalty': ['l2', None],
#                          'classification__solver': ['lbfgs', 'saga']},
#              scoring='accuracy', verbose=3)

# %%
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best validation score: {grid_search.best_score_}")
# Out:
# Best parameters: {'classification__C': 0.1, 'classification__max_iter': 100, 'classification__penalty': 'l2', 'classification__solver': 'lbfgs'}
# Best validation score: 0.77625

# %% [markdown]
# Сделайте выводы о влиянии выбора гиперпараметров на качество обучения линейной и SVC моделей. Также опишите, какие преобразования выборки/подбор каких гиперпараметров помогли добиться высокого качества на кросс-валидации в данной задаче.

# %% [markdown]
# <font color='MediumOrchid'>**Ваши выводы тут:**</font>

# %% [markdown]
# В случае SVC на результат больше всего влияет тип разделяющей поверхности. Лучший результат удалось достичь с использованием rbf. В случае с логистической регрессией большее влияние оказывал оптимизатор. Лучшие параметры подобранные для логистической регрессии выведены в ячейке выше, а для SVC лучшими параметрами оказались {'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__degree': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}

# %% [markdown]
# ### <font color='MediumSeaGreen'>**Задание 5 [1 балл][Bonus]**</font>

# %% [markdown]
# Найдите мем про SVM лучше чем этот:

# %% [markdown]
# ![meme.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![30927SVM 1.png](<attachment:30927SVM 1.png>)

# %% [markdown]
# Важно: самый простой способ вставить картинку будет через Google Colab (даже если вы изначально делали не в нем). Нажмите на **"+ Text"**, в появившейся ячейке сделайте **прикрепление картинки** (как на скринах). Тогда ваша картинка "зашифруется" и будет корректно отображаться при конвертации в html

# %% [markdown]
# ![Снимок экрана 2022-11-24 в 11.16.01.png](data:image/png;base64,...)![Снимок экрана 2022-11-24 в 11.16.10.png](data:image/png;base64,...)
